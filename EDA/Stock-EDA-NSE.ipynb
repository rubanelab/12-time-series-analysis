# %% [markdown]
# #### Time Series Analysis (EDA - NSEPython - Yahoo Finance)
# #### Lecture: (8) EDA-Stock Data

# %%
# !pip install nsepy

# %%
import datetime as dt

from nsepy import get_history as gh

# %%
from Descriptive import Descriptive

# %%
obj = Descriptive()
symbol = "TATACOFFEE"

# %%
# start = dt.datetime(2021,6,1)
# end = dt.datetime(2022,1,5)
# stk_data = gh(symbol=symbol, start=start, end=end)

# ValueError: cannot remove local variables from FrameLocalsProxy
# This error is caused by nsepy not being compatible with Python 3.13

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Just for info - </b> Since nsepy is no longer actively maintained, I use NSEPython
# </div>

# %%
# !pip install nsepython

# %%
# !pip install nsetools

# %%
from nsetools import Nse
nse = Nse()

# Check if a code is valid (returns True or False)
print(nse.is_valid_code('TATACONSUM')) 

# Fetch all valid stock codes as a list
# all_codes = nse.get_stock_codes()
# print(all_codes)
# Out:
# True

# %%
from nsepython import *

# %%
# url = 'https://www.nseindia.com/api/historical/cm/equity?symbol=TATACONSUM&series=["EQ"]&from=01-06-2025&to=05-01-2026'
url = 'https://www.nseindia.com/api/historical/cm/equity?symbol=TATACONSUM&series=["EQ"]&from=01-01-2025&to=31-01-2025'

payload = nsefetch(url)

print(type(payload))
print(payload)
# Out:
# <class 'dict'>
# {}

# %%
print(nse_eq("TATACONSUM"))
# Out:
# {}

# %%
# print(nse_quote("TATACONSUM"))

# %%
# stk_data = equity_history(
#     "TATACONSUM",
#     "EQ",
#     "01-01-2026",
#     "05-01-2026"
# )

# print(stk_data)

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Just for info - </b> Even nsepython not gives result, I switched to Yahoo Finance lib (yfinance)
# </div>

# %%
# !pip install yfinance

# %%
import numpy as np
import datetime as dt

import yfinance as yf

# This was created during the Data Sciecne module
from Descriptive import Descriptive
